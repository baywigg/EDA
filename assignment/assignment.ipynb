# %% [markdown]
# # Assignment: Exploratory Data Analysis
# ### `! git clone https://github.com/ds4e/EDA`
# ### Do Q1 and two other questions.

# %% [markdown]
# **Q1.** In class, we talked about how to compute the sample mean of a variable $X$,
# $$
# m(X) = \dfrac{1}{N} \sum_{i=1}^N x_i
# $$
# and sample covariance of two variables $X$ and $Y$,
# $$
# \text{cov}(X,Y) = \dfrac{1}{N} \sum_{i=1}^N (x_i - m(X))(y_i - m(Y))).
# $$
# Recall, the sample variance of $X$ is
# $$
# s^2 = \dfrac{1}{N} \sum_{i=1}^N (x_i - m(X))^2.
# $$
# It can be very helpful to understand some basic properties of these statistics. If you want to write your calculations on a piece of paper, take a photo, and upload that to your GitHub repo, that's probably easiest.
#
# 1. Show that $m(a + bX) = a+b \times m(X)$.
# 2. Show that $\text{cov}(X,a+bY) = b \times \text{cov}(X,Y)$
# 3. Show that $\text{cov}(a+bX,a+bX) = b^2 \text{cov}(X,X) $, and in particular that $\text{cov}(X,X) = s^2 $.
# 4. Instead of the mean, consider the median. Consider transformations that are non-decreasing (if $x\ge x'$, then $g(x)\ge g(x')$), like $2+5 \times X$ or $\text{arcsinh}(X)$. Is a non-decreasing transformation of the median the median of the transformed variable? Explain. Does your answer apply to any quantile? The IQR? The range?
# 5. Consider a non-decreasing transformation $g()$. Is is always true that $m(g(X))= g(m(X))$?

# %% [markdown]
# # 1.
# - We know that $m(X)$ can be written as:
#
# $$
# \dfrac{1}{N} \sum_{i=1}^{N} x_i
# $$
#
# - So, we can rewrite $m(a + bX)$ as :
#
# $$
# m(a + bX) = \dfrac{1}{N} \sum_{i=1}^{N} (a + b x_i)
# $$
#
# - We can now split this into:
#
# $$
# m(a + bX) = \dfrac{1}{N} \sum_{i=1}^{N} a + \dfrac{1}{N} \sum_{i=1}^{N} b x_i
# $$
#
# - We can factor out our constants:
#
# $$
# m(a + bX) = a \times \left( \dfrac{1}{N} \sum_{i=1}^{N} 1 \right) + b \times \left( \dfrac{1}{N} \sum_{i=1}^{N} x_i \right)
# $$
#
# - We can write the first term as so because the summation of ones up to $N$ is just $N$, and we can substitute $m(X)$ back in for the second term:
#
# $$
# m(a + bX) = a \times 1 + b \times m(X)
# $$
#
# - We have shown:
#
# $$
# m(a + bX) = a + b \times m(X).
# $$

# %% [markdown]
# # 2.
# - We know that the sample covariance of $X$ and $Y$ is defined as:
#
#   $$
#   \text{cov}(X,Y) = \dfrac{1}{N} \sum_{i=1}^{N} (x_i - m(X))(y_i - m(Y))
#   $$
#
# - So, we can rewrite $\text{cov}(X, a + bY)$ as:
#
#   $$
#   \text{cov}(X, a + bY) = \dfrac{1}{N} \sum_{i=1}^{N} (x_i - m(X))((a + b y_i) - m(a + bY))
#   $$
#
# - We can now expand the second term inside the summation:
#
#   $$
#   \text{cov}(X, a + bY) = \dfrac{1}{N} \sum_{i=1}^{N} (x_i - m(X)) \left( a + b y_i - m(a + bY) \right)
#   $$
#
# - We know from our previous proof that:
#
#   $$
#   m(a + bY) = a + b m(Y)
#   $$
#
# - Substituting this in, we get:
#
#   $$
#   \text{cov}(X, a + bY) = \dfrac{1}{N} \sum_{i=1}^{N} (x_i - m(X)) \left( a + b y_i - (a + b m(Y)) \right)
#   $$
#
# - Since $ a $ is a constant, it cancels out:
#
#   $$
#   \text{cov}(X, a + bY) = \dfrac{1}{N} \sum_{i=1}^{N} (x_i - m(X)) \left( b (y_i - m(Y)) \right)
#   $$
#
# - We can factor $ b $ out of the summation:
#
#   $$
#   \text{cov}(X, a + bY) = b \times \dfrac{1}{N} \sum_{i=1}^{N} (x_i - m(X))(y_i - m(Y))
#   $$
#
# - Recognizing the remaining term as $\text{cov}(X, Y)$, we conclude:
#
#   $$
#   \text{cov}(X, a + bY) = b \times \text{cov}(X, Y).
#   $$

# %% [markdown]
# # 3.
# - We know that the sample covariance of two variables $X$ and $Y$ is defined as:
#
#   $$
#   \text{cov}(X,Y) = \dfrac{1}{N} \sum_{i=1}^{N} (x_i - m(X))(y_i - m(Y))
#   $$
#
# - So, we can rewrite $\text{cov}(a + bX, a + bX)$ as:
#
#   $$
#   \text{cov}(a + bX, a + bX) = \dfrac{1}{N} \sum_{i=1}^{N} ((a + b x_i) - m(a + bX)) ((a + b x_i) - m(a + bX))
#   $$
#
# - From our previous proof, we know that:
#
#   $$
#   m(a + bX) = a + b m(X)
#   $$
#
# - Substituting this in:
#
#   $$
#   \text{cov}(a + bX, a + bX) = \dfrac{1}{N} \sum_{i=1}^{N} (a + b x_i - (a + b m(X))) (a + b x_i - (a + b m(X)))
#   $$
#
# - Since $ a $ is a constant, it cancels out:
#
#   $$
#   \text{cov}(a + bX, a + bX) = \dfrac{1}{N} \sum_{i=1}^{N} (b (x_i - m(X))) (b (x_i - m(X)))
#   $$
#
# - Factoring out $ b $ from both terms:
#
#   $$
#   \text{cov}(a + bX, a + bX) = b^2 \times \dfrac{1}{N} \sum_{i=1}^{N} (x_i - m(X)) (x_i - m(X))
#   $$
#
# - Recognizing the remaining sum as the definition of the sample variance:
#
#   $$
#   s^2 = \dfrac{1}{N} \sum_{i=1}^{N} (x_i - m(X))^2
#   $$
#
# - We conclude:
#
#   $$
#   \text{cov}(a + bX, a + bX) = b^2 s^2.
#   $$
#
# - In particular, since $\text{cov}(X,X) = s^2$, we have:
#
#   $$
#   \text{cov}(a + bX, a + bX) = b^2 \text{cov}(X,X).
#   $$

# %% [markdown]
# # 4.
#
# A non-decreasing transformation preserves the order of the data, so if you take the median of $X$ and then apply the transformation, you get the same result as if you applied the transformation first and then found the median. This works for any quantile, not just the median. However, measures like the IQR or the overall range involve differences between quantiles or extreme values, and a non-linear transformation can distort these differences, so the same property does not hold for them unless the transformation is linear.

# %% [markdown]
# # 5.
#
# This is true if $g$ is strictly increasing, and if it preserves order without flattening out any values. The median of $g(X)$ is just $g$ applied to the median of $X$. However, if $g$ is only non-decreasing, then this can fail because the transformation might collapse different values, so $m(g(X))$ may not equal $g(m(X))$.

# %% [markdown]
# **Q2.** This question looks at financial transfers from foreign entities to American universities. In particular, from which countries and giftors are the gifts coming from, and to which institutions are they going? For this question, `.groupby([vars]).count()` and `.groupby([vars]).sum()` will be especially useful to tally the number of occurrences and sum the values of those occurrences.
#
# 1. Load the `./data/ForeignGifts_edu.csv` dataset.
# 2. For `Foreign Gift Amount`, create a histogram and describe the variable. Describe your findings.
# 3. For `Gift Type`, create a histogram or value counts table. What proportion of the gifts are contracts, real estate, and monetary gifts?
# 4. Create a kernel density plot of the log of `Foreign Gift Amount`, and then a kernel density plot of the log of `Foreign Gift Amount` conditional on gift type. Do you notice any patterns?
# 5. What are the top 15 countries in terms of the number of gifts? What are the top 15 countries in terms of the amount given?
# 6. What are the top 15 institutions in terms of the total amount of money they receive? Make a histogram of the total amount received by all institutions.
# 7. Which giftors provide the most money, in total?

# %%
# loading libraries
import pandas as pd
import scipy
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# loading the foreign gifts dataset
foreign_gifts = pd.read_csv("./data/ForeignGifts_edu.csv")
foreign_gifts.head()
# Out:
#    ID   OPEID               Institution Name          City State  \
# 0   1  102000  Jacksonville State University  Jacksonville    AL
# 1   2  104700                Troy University          Troy    AL
# 2   3  105100          University of Alabama    Tuscaloosa    AL
# 3   4  105100          University of Alabama    Tuscaloosa    AL
# 4   5  105100          University of Alabama    Tuscaloosa    AL
#
#    Foreign Gift Received Date  Foreign Gift Amount      Gift Type  \
# 0                       43738               250000  Monetary Gift
# 1                       43592               463657       Contract
# 2                       43466              3649107       Contract
# 3                       43472                 1000       Contract
# 4                       43479                49476       Contract
#
#   Country of Giftor                          Giftor Name
# 0             CHINA                                  NaN
# 1             CHINA     Confucius Institute Headquarters
# ...

# %%
# Create histogram for the Gift Type column
foreign_gifts["Foreign Gift Amount"].hist()
# Print out description information about Gift Type
print(foreign_gifts["Foreign Gift Amount"].describe())
print("="*50)
# Print out the specific distribution of the counts of unique data in Gift Type
print(foreign_gifts["Foreign Gift Amount"].value_counts())
print("="*50)
# Check for any NA values
print(foreign_gifts["Foreign Gift Amount"].isna().sum())

# The Foreign Gift Amount histogram is right-skewed, with most values at the lower end and a few extreme outliers. The mean of 588,232.7 is much higher than the median of 94,615, indicating skewness. While most gifts are relatively small with the 25th-75th percentile being 5,700 to 376,142, a few large donations (up to $100M) significantly impact the distribution. The presence of negative values suggests refunds or corrections.
# Out:
# count    2.822100e+04
# mean     5.882327e+05
# std      3.222011e+06
# min     -5.377700e+05
# 25%      5.700000e+03
# 50%      9.461500e+04
# 75%      3.761420e+05
# max      1.000000e+08
# Name: Foreign Gift Amount, dtype: float64
# ...
# Foreign Gift Amount
# 100        581
# 250000     439
# 500000     427
# 50         324
# 1000       322
#           ...
# 213603       1
# 183909       1
# 546190       1
# 31544        1
# 1024469      1
# Name: count, Length: 16271, dtype: int64
# ...
# 0

# %%
# Create histogram for the Gift Type column
foreign_gifts["Gift Type"].hist()
# Print out description information about Gift Type
print(foreign_gifts["Gift Type"].describe())
print("="*50)
# Print out the specific distribution of the counts of unique data in Gift Type
print(foreign_gifts["Gift Type"].value_counts())
print("="*50)
# Check for any NA values
print(foreign_gifts["Gift Type"].isna().sum())

# For the Gift Type column, there are no null or missing values, with 3 unique values possible per row: Contract, Monetary Gift, or Real Estate. The most prevelant value is Contract, with Monetary Gift being behind by about 6,000, and Real Estate is by far the lowest with only 11 values in the 28,221 rows.
# Out:
# count        28221
# unique           3
# top       Contract
# freq         17274
# Name: Gift Type, dtype: object
# ...
# Gift Type
# Contract         17274
# Monetary Gift    10936
# Real Estate         11
# Name: count, dtype: int64
# ...
# 0

# %%
# Kernel Density Plot for the log of Foreign Gift Amount

# Ensure all values are positive before applying log
foreign_gifts_gift_amount_positive = foreign_gifts[foreign_gifts["Foreign Gift Amount"] > 0]

# Show kernel density plot
sns.kdeplot(x=np.log(foreign_gifts_gift_amount_positive["Foreign Gift Amount"])).set(title="KD Plot for Logarithm of Foreign Gift Amount")
# Out:
# [Text(0.5, 1.0, 'KD Plot for Logarithm of Foreign Gift Amount')]

# %%
# Kernel Density Plot for the log of Foreign Gift Amount conditional on gift type

fig = sns.kdeplot(data=foreign_gifts_gift_amount_positive, x="Foreign Gift Amount", hue="Gift Type", common_norm=False).set(title="KD Plot for Logarithm of Foreign Gift Amount Conditional on Gift Type")

# %%
# The log-transformed Foreign Gift Amount shows a right-skewed distribution, indicating most gifts are small with fewer large ones. When conditioned on Gift Type, Monetary Gifts dominate lower amounts, while Contracts and Real Estate have broader distributions but lower densities. The distinct peaks suggest some gift types follow standardized amounts.

# %%
# Get the value counts of the country of giftor, as each row represents a gift, then sort them from largest to smallest
top_countries_gifts = foreign_gifts["Country of Giftor"].value_counts().sort_values(ascending=False).reset_index()

# Display top 15 countries
top_countries_gifts.head(15)
# Out:
#    Country of Giftor  count
# 0            ENGLAND   3655
# 1              CHINA   2461
# 2             CANADA   2344
# 3              JAPAN   1896
# 4        SWITZERLAND   1676
# 5       SAUDI ARABIA   1610
# 6             FRANCE   1437
# 7            GERMANY   1394
# 8          HONG KONG   1080
# 9        SOUTH KOREA    811
# 10             QATAR    693
# 11   THE NETHERLANDS    512
# 12             KOREA    452
# 13             INDIA    434
# 14            TAIWAN    381

# %%
# Group the data by country, then extract just the foreign gift amount, sum it, then sort from high to low
top_countries_amount = foreign_gifts.groupby("Country of Giftor")["Foreign Gift Amount"].sum().sort_values(ascending=False).reset_index()

# Display top 15 countries
top_countries_amount.head(15)
# Out:
#        Country of Giftor  Foreign Gift Amount
# 0                  QATAR           2706240869
# 1                ENGLAND           1464906771
# 2                  CHINA           1237952112
# 3           SAUDI ARABIA           1065205930
# 4                BERMUDA            899593972
# 5                 CANADA            898160656
# 6              HONG KONG            887402529
# 7                  JAPAN            655954776
# 8            SWITZERLAND            619899445
# 9                  INDIA            539556490
# 10               GERMANY            442475605
# 11  UNITED ARAB EMIRATES            431396357
# 12                FRANCE            405839396
# 13             SINGAPORE            401157692
# 14             AUSTRALIA            248409202

# %%
# Group the data by institution, then extract just the foreign gift amount, sum it, then sort from high to low
top_institutions_amount = foreign_gifts.groupby("Institution Name")["Foreign Gift Amount"].sum().sort_values(ascending=False).reset_index()

# Display top 15 institutions
top_institutions_amount.head(15)
# Out:
#                                  Institution Name  Foreign Gift Amount
# 0                      Carnegie Mellon University           1477922504
# 1                              Cornell University           1289937761
# 2                              Harvard University            954803610
# 3           Massachusetts Institute of Technology            859071692
# 4                                 Yale University            613441311
# 5                            Texas A&M University            521455050
# 6                        Johns Hopkins University            502409595
# 7                         Northwestern University            402316221
# 8                           Georgetown University            379950511
# 9                     University of Chicago (The)            364544338
# 10                 University of Colorado Boulder            360173159
# 11                                Duke University            343699498
# ...

# %%
# Create histogram with seaborn, with the x value the name, and the y value the gift amount
fig = sns.barplot(x="Institution Name", y="Foreign Gift Amount", data=top_institutions_amount.head(15))
# rotate the labels so they do not overlap
fig.set_xticklabels(fig.get_xticklabels(), rotation=90)
# Out:
# /var/folders/rw/kqv4w2bj5hx2v1ln61zfm4pr0000gn/T/ipykernel_35701/2410943920.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   fig.set_xticklabels(fig.get_xticklabels(), rotation=90)
# [Text(0, 0, 'Carnegie Mellon University'),
#  Text(1, 0, 'Cornell University'),
#  Text(2, 0, 'Harvard University'),
#  Text(3, 0, 'Massachusetts Institute of Technology'),
#  Text(4, 0, 'Yale University'),
#  Text(5, 0, 'Texas A&M University'),
#  Text(6, 0, 'Johns Hopkins University'),
#  Text(7, 0, 'Northwestern University'),
#  Text(8, 0, 'Georgetown University'),
#  Text(9, 0, 'University of Chicago (The)'),
#  Text(10, 0, 'University of Colorado Boulder'),
#  Text(11, 0, 'Duke University'),
#  Text(12, 0, 'Brigham Young University'),
#  Text(13, 0, 'Stanford University'),
#  Text(14, 0, 'University of Texas MD Anderson Cancer Center')]

# %%
# Group the data by name, then extract just the foreign gift amount, sum it, then sort from high to low
giftors_most_money = foreign_gifts.groupby("Giftor Name")["Foreign Gift Amount"].sum().sort_values(ascending=False).reset_index()

giftors_most_money.head(15)
# Out:
#                             Giftor Name  Foreign Gift Amount
# 0                      Qatar Foundation           1166503744
# 1   Qatar Foundation/Qatar National Res            796197000
# 2        Qatar Foundation for Education            373945215
# 3                             Anonymous            338793629
# 4        Saudi Arabian Cultural Mission            275221475
# 5                                   HCL            190000000
# 6         Church of Jesus Christ of LDS            185203715
# 7    Emirates Institute for Advanced Sc            170641244
# 8                                   QIC            148355497
# 9                          Anonymous #9             96334996
# 10         Qatar National Research Fund             79021705
# 11           Government of Saudi Arabia             75192434
# 12                    Contracting Party             69996984
# 13                      CMKL University             67700000
# ...

# %% [markdown]
# **Q3.** This question uses the Airbnb data to practice making visualizations.
#
#   1. Load the `./data/airbnb_hw.csv` data with Pandas. This provides a dataset of AirBnB rental properties for New York City.
#   2. What are are the dimensions of the data? How many observations are there? What are the variables included? Use `.head()` to examine the first few rows of data.
#   3. Cross tabulate `Room Type` and `Property Type`. What patterns do you see in what kinds of rentals are available? For which kinds of properties are private rooms more common than renting the entire property?
#   4. For `Price`, make a histogram, kernel density, box plot, and a statistical description of the variable. Are the data badly scaled? Are there many outliers? Use `log` to transform price into a new variable, `price_log`, and take these steps again.
#   5. Make a scatterplot of `price_log` and `Beds`. Describe what you see. Use `.groupby()` to compute a desciption of `Price` conditional on/grouped by the number of beds. Describe any patterns you see in the average price and standard deviation in prices.
#   6. Make a scatterplot of `price_log` and `Beds`, but color the graph by `Room Type` and `Property Type`. What patterns do you see? Compute a description of `Price` conditional on `Room Type` and `Property Type`. Which Room Type and Property Type have the highest prices on average? Which have the highest standard deviation? Does the mean or median appear to be a more reliable estimate of central tendency, and explain why?
#   7. We've looked a bit at this `price_log` and `Beds` scatterplot. Use seaborn to make a `jointplot` with `kind=hex`. Where are the data actually distributed? How does it affect the way you think about the plots in 5 and 6?

# %% [markdown]
# **Q4.** This question looks at a time series of the number of active oil drilling rigs in the United States over time. The data comes from the Energy Information Agency.
#
# 1. Load `./data/drilling_rigs.csv` and examine the data. How many observations? How many variables? Are numeric variables correctly read in by Pandas, or will some variables have to be typecast/coerced? Explain clearly how these data need to be cleaned.
# 2. To convert the `Month` variable to an ordered datetime variable, use `df['time'] = pd.to_datetime(df['Month'], format='mixed')`.
# 3. Let's look at `Active Well Service Rig Count (Number of Rigs)`, which is the total number of rigs over time. Make a line plot of this time series. Describe what you see.
# 4. Instead of levels, we want to look at change over time. Compute the first difference of  `Active Well Service Rig Count (Number of Rigs)` and plot it over time. Describe what you see.
# 5. The first two columns are the number of onshore and offshore rigs, respectively. Melt these columns and plot the resulting series.

# %%
# Load drilling
drilling = pd.read_csv("./data/drilling_rigs.csv")

print("="*50)
# Print the number of observations (rows) and variables (columns)
print("Number of observations:", drilling.shape[0])
print("Number of variables:", drilling.shape[1])
print("="*50)
# Display the data types of each column
print("Data types of each column:")
print(drilling.dtypes)
print("="*50)
# Get an overall summary of the dataframe (includes non-null counts and memory usage)
print("DataFrame info:")
drilling.info()
print("="*50)
# Descriptive statistics for numeric columns
print("Descriptive statistics (numeric columns):")
print(drilling.describe())
print("="*50)
# Check for missing values in each column
print("Missing values per column:")
print(drilling.isnull().sum())
print("="*50)

drilling.head()
# Out:
# ...
# Number of observations: 623
# Number of variables: 10
# ...
# Data types of each column:
# Month                                                                                          object
# Crude Oil and Natural Gas Rotary Rigs in Operation, Onshore (Number of Rigs)                    int64
# Crude Oil and Natural Gas Rotary Rigs in Operation, Offshore (Number of Rigs)                   int64
# Crude Oil Rotary Rigs in Operation, Total (Number of Rigs)                                     object
# Natural Gas Rotary Rigs in Operation, Total (Number of Rigs)                                   object
# Crude Oil and Natural Gas Rotary Rigs in Operation, Horizontal Trajectory (Number of Rigs)     object
# Crude Oil and Natural Gas Rotary Rigs in Operation, Directional Trajectory (Number of Rigs)    object
# Crude Oil and Natural Gas Rotary Rigs in Operation, Vertical Trajectory (Number of Rigs)       object
# ...

# %%
# There are 623 observations, with 10 variables
# Only 3 of the 10 variables were correctly read as integers
# The remaining columns that should represent numeric data are read as object because they contain the string "Not Available". This string is not interpreted as missing by Pandas, so these columns remain as text
# To clean these, 'Not Available' should be replaced with NaN, which is the datatype that Pandas can recognize and still have the int datatype in the column. Then, call the to_numeric() function on the dataset, with errors='coerce'
# Lastly, The Month column is stored as an object. It would be useful to convert this to a datetime type for any time series analysis.

# %%
# List of columns that should be numeric but are currently object due to "Not Available"
cols_to_convert = [
    'Crude Oil Rotary Rigs in Operation, Total (Number of Rigs)',
    'Natural Gas Rotary Rigs in Operation, Total (Number of Rigs)',
    'Crude Oil and Natural Gas Rotary Rigs in Operation, Horizontal Trajectory (Number of Rigs)',
    'Crude Oil and Natural Gas Rotary Rigs in Operation, Directional Trajectory (Number of Rigs)',
    'Crude Oil and Natural Gas Rotary Rigs in Operation, Vertical Trajectory (Number of Rigs)',
    'Active Well Service Rig Count (Number of Rigs)'
]

# Replace "Not Available" with NaN in the specified columns
drilling[cols_to_convert] = drilling[cols_to_convert].replace("Not Available", np.nan)

# Convert these columns to numeric (will coerce any remaining issues to NaN)
for col in cols_to_convert:
    drilling[col] = pd.to_numeric(drilling[col], errors='coerce')
drilling['Time'] = pd.to_datetime(drilling['Month'], format='mixed')

# %%
# Plotting the Active Well Service Rig Count time series
plt.figure(figsize=(12,6))
plt.plot(drilling['Time'], drilling['Active Well Service Rig Count (Number of Rigs)'], marker='o', linestyle='-')
plt.title('Active Well Service Rig Count Over Time')
plt.xlabel('Time')
plt.ylabel('Active Well Service Rig Count (Number of Rigs)')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# %%
# Compute the first difference
drilling['Rig Count Change'] = drilling['Active Well Service Rig Count (Number of Rigs)'].diff()

# Set figure size
plt.figure(figsize=(12, 6))

# Plot the first difference
plt.plot(drilling['Time'], drilling['Rig Count Change'], marker='o', linestyle='-', markersize=3, label='Change in Active Well Service Rig Count')

plt.title('Active Well Service Rig Count Over Time')
plt.xlabel('Month')
plt.ylabel('Active Well Service Rig Count (Number of Rigs)')
plt.xticks(rotation=90)
plt.grid(True)


# Add a horizontal line at y=0 for reference
plt.axhline(y=0, color='black', linestyle='--', linewidth=1)

# Show the legend
plt.legend()

# Show the plot
plt.show()

# %%
# The graph shows how the number of active rigs changes from month to month. In the early years (1970s–1990s), the rig count went up and down a lot, with some really big drops, likely due to oil price crashes or industry slowdowns. After 2000, the changes became smaller, meaning the industry got more stable. However, there was a big drop around 2020, likely because of the COVID-19 pandemic. Overall, the chart shows that the oil industry has had big ups and downs over time, but it seems to have steadied out in recent years.

# %%
# Melt the DataFrame to reshape onshore and offshore counts into a single column
drilling_melted = drilling.melt(id_vars=['Time'], 
                     value_vars=[
                         'Crude Oil and Natural Gas Rotary Rigs in Operation, Onshore (Number of Rigs)',
                         'Crude Oil and Natural Gas Rotary Rigs in Operation, Offshore (Number of Rigs)'
                     ],
                     var_name='Rig Type', 
                     value_name='Rig Count')

# Rename categories for clarity
drilling_melted['Rig Type'] = drilling_melted['Rig Type'].replace({
    'Crude Oil and Natural Gas Rotary Rigs in Operation, Onshore (Number of Rigs)': 'Onshore Rigs',
    'Crude Oil and Natural Gas Rotary Rigs in Operation, Offshore (Number of Rigs)': 'Offshore Rigs'
})

# Set figure size
plt.figure(figsize=(12, 6))

# Line plot of both rig types
sns.lineplot(data=drilling_melted, x='Time', y='Rig Count', hue='Rig Type', marker='o')

# Formatting the plot
plt.xlabel('Year')
plt.ylabel('Number of Rigs')
plt.title('Onshore vs Offshore Rig Counts Over Time')
plt.legend(title='Rig Type')
plt.xticks(rotation=45)

# Show the plot
plt.show()
